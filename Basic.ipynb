# %% [markdown]
# ##Pandas : It is a fast,powerful,flexible and easy to use open source data analysis and manipulation tool,built on top ofthe Python

# %% [markdown]
# ##Pandas series: It is like a column in table .It is a 1D array holding data of any type

# %%
# importing pandas
import pandas as pd
import numpy as np

# %% [markdown]
# ##Series from lists

# %%
#String
country=["India","Pakistan","USA","Nepal","Srilanka"]
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: str

# %%
#Integer
runs=[12,13,15,17,18,19]
pd.Series(runs)
# Out:
# 0    12
# 1    13
# 2    15
# 3    17
# 4    18
# 5    19
# dtype: int64

# %%
#Custom index
marks=[65,78,29,98]
subjects=["Maths","English","Science","Hindi"]
pd.Series(marks,index=subjects)
# Out:
# Maths      65
# English    78
# Science    29
# Hindi      98
# dtype: int64

# %%
#Setting a name
marks=pd.Series(marks,index=subjects,name="simran ke marks")
print(marks)
# Out:
# Maths      65
# English    78
# Science    29
# Hindi      98
# Name: simran ke marks, dtype: int64

# %% [markdown]
# ##Series from dict

# %%
marks={"Maths":67,"English":78,"Hindi":90,"Science":89}
a=pd.Series(marks)
a
# Out:
# Maths      67
# English    78
# Hindi      90
# Science    89
# dtype: int64

# %% [markdown]
# ##Series Attributes

# %%
#size=Number of items in series
a.size
# Out:
# 4

# %%
#dtype=type of the elemnets in series
a.dtype
