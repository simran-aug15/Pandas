# %% [markdown]
# ### A collection of pandas timestamp (to store multiple date and time)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Example 
dt_index=pd.DatetimeIndex(['2023/1/1','2021/1/1','2022/1/1'])
dt_index
# Out:
# DatetimeIndex(['2023-01-01', '2021-01-01', '2022-01-01'], dtype='datetime64[us]', freq=None)

# %%
# using python datetime object
import datetime as dt
x=pd.DatetimeIndex([dt.datetime(2023,1,1),dt.datetime(2022,1,1),dt.datetime(2021,1,1)])
x
# Out:
# DatetimeIndex(['2023-01-01', '2022-01-01', '2021-01-01'], dtype='datetime64[us]', freq=None)

# %%
# using pd.timestamps
x=pd.DatetimeIndex([pd.Timestamp(2023,1,1),pd.Timestamp(2022,1,1),pd.Timestamp(2021,1,1)])
x
# Out:
# DatetimeIndex(['2023-01-01', '2022-01-01', '2021-01-01'], dtype='datetime64[us]', freq=None)

# %%
# Using datetimeindex as series index
a=pd.Series([1,2,3],index= dt_index)
a
# Out:
# 2023-01-01    1
# 2021-01-01    2
# 2022-01-01    3
# dtype: int64

# %% [markdown]
# ### date_range_functions

# %%
# generate daily date in given range
x=pd.date_range(start='2023/1/5',end='2023/1/31',freq='D')
x
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                '2023-01-29', '2023-01-30', '2023-01-31'],
#               dtype='datetime64[us]', freq='D')

# %%
# alternate days in a given range 
x=pd.date_range(start='2023/1/5',end='2023/2/5',freq='2D')
x
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-07', '2023-01-09', '2023-01-11',
#                '2023-01-13', '2023-01-15', '2023-01-17', '2023-01-19',
#                '2023-01-21', '2023-01-23', '2023-01-25', '2023-01-27',
#                '2023-01-29', '2023-01-31', '2023-02-02', '2023-02-04'],
#               dtype='datetime64[us]', freq='2D')

# %%
# B : Bussiness days : days from (Mon-Fri)
x=pd.date_range(start='2023/1/5',end='2023/2/28',freq='B')
x
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-06', '2023-01-09', '2023-01-10',
#                '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26',
#                '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01',
#                '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07',
#                '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13',
#                '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17',
#                '2023-02-20', '2023-02-21', '2023-02-22', '2023-02-23',
#                '2023-02-24', '2023-02-27', '2023-02-28'],
#               dtype='datetime64[us]', freq='B')

# %%
# W : one week per day : Thu
x=pd.date_range(start='2023/1/5',end='2023/2/28',freq='W-Thu')
x
# Out:
# C:\Users\samar\AppData\Local\Temp\ipykernel_4240\2541363760.py:2: Pandas4Warning: 'W-Thu' is deprecated and will be removed in a future version, please use 'W-THU' instead.
#   x=pd.date_range(start='2023/1/5',end='2023/2/28',freq='W-Thu')
# DatetimeIndex(['2023-01-05', '2023-01-12', '2023-01-19', '2023-01-26',
#                '2023-02-02', '2023-02-09', '2023-02-16', '2023-02-23'],
#               dtype='datetime64[us]', freq='W-THU')

# %%
# H : Hourly data
x=pd.date_range(start='2023/1/5',end='2023/2/28',freq='h')
x
# Out:
# DatetimeIndex(['2023-01-05 00:00:00', '2023-01-05 01:00:00',
#                '2023-01-05 02:00:00', '2023-01-05 03:00:00',
#                '2023-01-05 04:00:00', '2023-01-05 05:00:00',
#                '2023-01-05 06:00:00', '2023-01-05 07:00:00',
#                '2023-01-05 08:00:00', '2023-01-05 09:00:00',
#                ...
#                '2023-02-27 15:00:00', '2023-02-27 16:00:00',
#                '2023-02-27 17:00:00', '2023-02-27 18:00:00',
#                '2023-02-27 19:00:00', '2023-02-27 20:00:00',
#                '2023-02-27 21:00:00', '2023-02-27 22:00:00',
#                '2023-02-27 23:00:00', '2023-02-28 00:00:00'],
#               dtype='datetime64[us]', length=1297, freq='h')

# %%
# ME : Month end data
x=pd.date_range(start='2023/1/5',end='2023/2/28',freq='ME')
x
# Out:
# DatetimeIndex(['2023-01-31', '2023-02-28'], dtype='datetime64[us]', freq='ME')

# %%
# h : Hourly data at 5H
x=pd.date_range(start='2023/1/5',end='2023/2/28',freq='5h')
x
# Out:
# DatetimeIndex(['2023-01-05 00:00:00', '2023-01-05 05:00:00',
#                '2023-01-05 10:00:00', '2023-01-05 15:00:00',
#                '2023-01-05 20:00:00', '2023-01-06 01:00:00',
#                '2023-01-06 06:00:00', '2023-01-06 11:00:00',
#                '2023-01-06 16:00:00', '2023-01-06 21:00:00',
#                ...
#                '2023-02-26 02:00:00', '2023-02-26 07:00:00',
#                '2023-02-26 12:00:00', '2023-02-26 17:00:00',
#                '2023-02-26 22:00:00', '2023-02-27 03:00:00',
#                '2023-02-27 08:00:00', '2023-02-27 13:00:00',
#                '2023-02-27 18:00:00', '2023-02-27 23:00:00'],
#               dtype='datetime64[us]', length=260, freq='5h')

# %%
# MS : Month start data
x=pd.date_range(start='2023/1/5',end='2023/5/28',freq='MS')
x
# Out:
# DatetimeIndex(['2023-02-01', '2023-03-01', '2023-04-01', '2023-05-01'], dtype='datetime64[us]', freq='MS')

# %%
# YE : Year end data
x=pd.date_range(start='2023/1/5',end='2029/2/28',freq='YE')
x
# Out:
# DatetimeIndex(['2023-12-31', '2024-12-31', '2025-12-31', '2026-12-31',
#                '2027-12-31', '2028-12-31'],
#               dtype='datetime64[us]', freq='YE-DEC')

# %%
# Using periods(no. of result)
x=pd.date_range(start='2023/1/5',periods=25,freq='D')
x
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                '2023-01-29'],
#               dtype='datetime64[us]', freq='D')

# %% [markdown]
# ### to_datetime function

# %%
# simple Series example
s=pd.Series(['2023/1/1','2022/8/1','2021/11/1'])
pd.to_datetime(s).dt.month_name()
# Out:
# 0     January
# 1      August
# 2    November
# dtype: str

# %%
# with simple example u can fetch day year and month also
s=pd.Series(['2023/1/1','2005/8/15','2006/11/30'])
pd.to_datetime(s).dt.day_name()
# Out:
# 0      Sunday
# 1      Monday
# 2    Thursday
# dtype: str

# %%
# with erroes
s=pd.Series(['2023/1/1','2022/1/1','2021/1/1'])
# converting it into a date time
x=pd.to_datetime(s,errors='coerce')
x
# Out:
# 0   2023-01-01
# 1   2022-01-01
# 2   2021-01-01
# dtype: datetime64[us]

# %%
# fetch month from s
pd.to_datetime(s).dt.month
# Out:
# 0    1
# 1    1
# 2    1
# dtype: int32

# %%
# importing dataset
df=pd.read_csv('expense_data.csv')
df.shape
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    str
#  1   Account         277 non-null    str
#  2   Category        277 non-null    str
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    str
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    str
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    str
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), str(6)
# memory usage: 23.9 KB

# %%
# converting into datetime
df['Date']=pd.to_datetime(df['Date'])
df['Date']
# Out:
# 0     2022-03-02 10:11:00
# 1     2022-03-02 10:11:00
# 2     2022-03-01 19:50:00
# 3     2022-03-01 18:56:00
# 4     2022-03-01 18:22:00
#               ...
# 272   2021-11-22 14:16:00
# 273   2021-11-22 14:16:00
# 274   2021-11-21 17:07:00
# 275   2021-11-21 15:50:00
# 276   2021-11-21 13:30:00
# Name: Date, Length: 277, dtype: datetime64[us]

# %%
# Fetch year
df['Date'].dt.year
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 272    2021
# 273    2021
# 274    2021
# 275    2021
# 276    2021
# Name: Date, Length: 277, dtype: int32

# %%
# Dt accessor
# Accessor object for datetimelike properties of the Series values

df['Date'].dt.is_quarter_start
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 272    False
# 273    False
# 274    False
# 275    False
# 276    False
# Name: Date, Length: 277, dtype: bool

# %%
# plot graph
plt.plot(df['Date'],df['INR'])

# %%
# day namewise bar chart/month wise
df['day_name']=df['Date'].dt.day_name()
df.head()
df.groupby('day_name')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='day_name'>

# %%
df['month_name']=df['Date'].dt.month_name()
df.head()
df.groupby('month_name')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='month_name'>
