# %% [markdown]
# ### Timestamp reference particular moments in time(example : 15 aug 2005 at 7:15 pm)

# %% [markdown]
# ### Creating Timestamp objects

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# creating an timestamp object
pd.Timestamp('2023-1-5')
type(pd.Timestamp('2023-1-5'))
# Out:
# pandas.Timestamp

# %%
# Variattions 
a=pd.Timestamp('2023-1-5')
a
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
b=pd.Timestamp('2026/1/15')
b
# Out:
# Timestamp('2026-01-15 00:00:00')

# %%
#only year
a=pd.Timestamp('2023')
a
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
#using text 
a=pd.Timestamp('30th november 2006')
a
# Out:
# Timestamp('2006-11-30 00:00:00')

# %%
# prodoviding time also
a=pd.Timestamp('15th Feb 2016 7:12 AM')
a
# Out:
# Timestamp('2016-02-15 07:12:00')

# %%
# using datetime .datetime object
#This is how you can display datetime using python
import datetime as dt
a=dt.datetime(2023,1,4,21,56)
a
# Out:
# datetime.datetime(2023, 1, 4, 21, 56)

# %%
# Using Timestamp
a=pd.Timestamp(dt.datetime(2023,5,9,21,7))
a
# Out:
# Timestamp('2023-05-09 21:07:00')

# %%
# Fetching attribute : By using this U can easily fetch values from your data set
a=pd.Timestamp(dt.datetime(2023,5,9,21,7))
a.year
a.minute
# Out:
# 7

# %%
# why separate objects to handle data and time when python already has datetime functionality?

# 1.syntax wise datetime is very convenient
# 2.But the performance takes a hit while working with huge data. List vs Numpy Array
# 3.The weaknesses of Python's datetime format inspired the NumPy team to add a set of native time series data type to NumPy.
# 4.The datetime64 dtype encodes dates as 64-bit integers, and thus allows arrays of dates to be represented very compactly.

# %%
import numpy as np
date = np.array('2015-07-04', dtype=np.datetime64) # dtype= np.datetime64 tells Numpy to store it as data type
date
# Out:
# array('2015-07-04', dtype='datetime64[D]')

# %%
date + np.arange(12) # This creates a numbers from 0 to 11
#yyyy-MM-D + days like : 2015-07-04 + 0days
#                        2015-07-04 + 1days=2015-07-05
# Out:
# array(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#        '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#        '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#       dtype='datetime64[D]')

# %%
# Because of the uniform type in NumPy datetime64 arrays, this type of operation can be accomplished much more quickly than if we were working directly with Python's datetime objects, especially as arrays get large

# Pandas Timestamp object combines the ease-of-use of python datetime with the efficient storage and vectorized interface of numpy.datetime64

# From a group of these Timestamp objects, Pandas can construct a DatetimeIndex that can be used to index data in a Series or DataFrame

# DatetimeIndex Object
