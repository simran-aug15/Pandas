# %% [markdown]
# ### Important Methods of DataFrame

# %%
import numpy as np
import pandas as pd

# %%
#Import the data set
ipl=pd.read_csv("ipl-matches.csv")
movies=pd.read_csv('movies.csv')
batsman=pd.read_csv('batsman_runs_ipl.csv')

# %%
#value_counts : This count the number of values (Series,DataFrame)
